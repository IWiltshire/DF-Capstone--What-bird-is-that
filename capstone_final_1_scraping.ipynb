# %%
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
import requests
import re
import os

# %% [markdown]
# #### Gathering the data

# %% [markdown]
# By looking at various lists online, and taking into account my own observations of birds, I estimated that the nineteen most common birds in London are in the following list:
# - Wren
# - Robin
# - House sparrow
# - Wood pigeon
# - Rock dove/feral pigeon
# - Collared dove
# - Blackbird
# - Blue tit
# - Great tit
# - Coal tit
# - Chaffinch
# - Greenfinch
# - Goldfinch
# - Starling
# - Herring gull
# - Black-headed gull
# - Carrion crow
# - Jackdaw
# - Magpie
#
# I'll get data on each of these birds by scraping from the RSPB website

# %%
## List of relevant webpages
bird_urls = ['https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/wren/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/robin/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/house-sparrow/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/woodpigeon/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/blackbird/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/chaffinch/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/blue-tit/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/great-tit/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/starling/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/goldfinch/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/collared-dove/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/coal-tit/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/rock-dove/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/herring-gull/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/jackdaw/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/carrion-crow/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/black-headed-gull/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/greenfinch/',
             'https://www.rspb.org.uk/birds-and-wildlife/wildlife-guides/bird-a-z/magpie/'
             ]
## This is approximately in order of most common to least

# %%
len(bird_urls) ## Length matches
# Out:
# 19

# %%
## Testing that I can connect to a single page
site = bird_urls[0] ## Wren RSPB page
resp = requests.get(site, 'html.parser')
resp ## Response code of 200 indicates that scraping will work
# Out:
# <Response [200]>

# %%
bird_data = [] ## Empty list
colours = ['Black','Brown','Grey','Yellow','Orange','Red','Pink','Blue','Green', 'White'] ## List of various colours - for use with beak characteristics later

for link in bird_urls:
    site = link ## url of RSPB page
    resp = requests.get(site, 'html.parser')
    soup = BeautifulSoup(resp.text, 'html.parser') ## Reading the url into Python using BeautifulSoup

    species = soup.find('h1', class_='species-hero__page-title').text ## Species of bird
    sci_name = soup.find('li', class_='species-hero__stats-item').strong.text ## Scientific name
    diet = soup.find('div', class_='key-information__section').p.text ## Dietary information

    measurements = soup.find('div', class_='species-measurements-population__measurements').find_all('dl', class_='species-measurements-population__details') ## Various physical measurements
    length_cm = measurements[0].find('dd', class_='species-measurements-population__details-content').text  ## Length of the bird in centimetres
    length_cm = re.search(r'([\d\.?]*-*[\d\.?]+\s?cm)',length_cm).group(1)
    wingspan_cm = measurements[1].find('dd', class_='species-measurements-population__details-content').text ## Wingspan of the bird in centimetres
    wingspan_cm = re.search(r'([\d\.?]*-*[\d\.?]+\s?cm)',wingspan_cm).group(1)
    weight_g = measurements[2].find('dd', class_='species-measurements-population__details-content').text ## Weight of the bird in grams
    weight_g = re.search(r'([\d\.?]*-*[\d\.?]+\s?g)',weight_g).group(1)

    population = soup.find('div', class_='species-measurements-population__population').find_all('dd', class_='species-measurements-population__details-content') ## Population measurements
    breeding_pop = population[0].text   ## Breeding population: the number of pairs breeding annually
    breeding_pop = re.search(r'([\d+\.?]+[\d+,?]+\s\w+)',breeding_pop).group(1)
    try:
        wintering_pop = population[1].text ## Wintering population: the number of individuals present from October to March
        wintering_pop = re.search(r'([\d+\.?]+[\d+,?]+\s\w+)',wintering_pop).group(1)
    except IndexError:
        wintering_pop = np.NAN  ## Resident birds may not have a wintering population
    except AttributeError:
        wintering_pop = np.NAN ## This continues from the previous error
    ## NOTE: For blue tit and black-headed gull, population[2] would be Europe. It could feasibly be Africa or Asia for other birds on the RSPB website.
    ## NOTE: This code only works as is because I'm looking at common UK species - they all have a breeding population in the UK; Birds such as the aquatic warbler have 'UK Passage' as population[0]

    physical_feat = soup.find_all('div', class_='key-information__species-variation__features') ## Various physical characteristics

    num_species_variations = len(physical_feat) ## The number of significant intra-species variations arising from age, sexual dimorphism, season, etc
    variation_names = soup.find_all('h4', class_='key-information__species-variation__heading') ## The name for each variation
    variation_names = [x.text for x in variation_names]

    for i in range(num_species_variations):
        variation = variation_names[i] ## The specific variation
        identifiers = physical_feat[i].find_all('div', class_='filter-block__tags-block')
        feather_col = identifiers[0].find_all('span', class_='filter-block__tags-block__tag') ## Feather colours
        feather_col = [x.text for x in feather_col]
        leg_col = identifiers[1].find_all('span', class_='filter-block__tags-block__tag') ## Leg colours
        leg_col = [x.text for x in leg_col]
        beak_char = identifiers[2].find_all('span', class_='filter-block__tags-block__tag') ## All the beak characteristics
        beak_char = [x.text for x in beak_char]
        beak_col = [word for word in beak_char if word in colours] ## Beak colours
        beak_shape = [word for word in beak_char if word not in beak_col] ## Beak shape
        habitats = identifiers[3].find_all('span', class_='filter-block__tags-block__tag')
        habitats = [x.text for x in habitats]

        locals()[f'bird_info_{i}'] = [species,sci_name,diet,length_cm,wingspan_cm,weight_g,breeding_pop,wintering_pop,variation,feather_col,leg_col,beak_col,beak_shape,habitats] ## Creating a list with all the information for each variation of every bird

        bird_data.append(locals()[f'bird_info_{i}']) ## Adding our list to the big bird data

# %%
bird_data ## Checking that everything has worked
# Out:
# [['Wren',
#   'Troglodytes troglodytes',
#   '9-10cm',
#   '13-17cm',
#   '7-12g',
#   '11,000,000 territories',
#   nan,
#   'Wren',
#   ['Brown', 'Cream/buff', 'White'],
#   ['Brown', 'Pink'],
#   ['Black'],
#   ['Short', 'Curved', 'Thin'],
#   ['Woodland', 'Farmland', 'Heathland', 'Urban and suburban']],
#  ['Robin',
#   'Erithacus rubecula',
#   '14cm',
#   '20-22cm',
#   '14-21g',
#   '7,350,000 territories',
#   nan,
#   'Robin (adult)',
#   ['Brown', 'Cream/buff', 'Grey', 'Orange', 'Red', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Robin',
#   'Erithacus rubecula',
#   '14cm',
#   '20-22cm',
#   '14-21g',
#   '7,350,000 territories',
#   nan,
#   'Robin (juvenile)',
#   ['Brown', 'Cream/buff', 'Orange', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['House sparrow',
#   'Passer domesticus',
#   '14-15cm',
#   '5cm',
#   '24-38g',
#   '5,300,000 pairs',
#   nan,
#   'House sparrow (adult male)',
#   ['Black', 'Brown', 'Cream/buff', 'Grey', 'White'],
#   ['Brown', 'Pink'],
#   ['Black', 'Brown'],
#   ['Short', 'Chunky'],
#   ['Farmland', 'Urban and suburban']],
#  ['House sparrow',
#   'Passer domesticus',
#   '14-15cm',
#   '5cm',
#   '24-38g',
#   '5,300,000 pairs',
#   nan,
#   'House sparrow (adult female)',
#   ['Brown', 'Cream/buff', 'Grey'],
#   ['Brown', 'Pink'],
#   ['Black', 'Brown'],
#   ['Short', 'Chunky'],
#   ['Farmland', 'Urban and suburban']],
#  ['Woodpigeon',
#   'Columba palumbus',
#   '40-42cm',
#   '75-80cm',
#   '480-550g',
#   '5,150,000 pairs',
#   nan,
#   'Woodpigeon (adult)',
#   ['Black', 'Blue', 'Brown', 'Grey', 'Pink/purple', 'White'],
#   ['Brown', 'Pink', 'Red'],
#   ['Black', 'Brown', 'Orange'],
#   ['Medium length', 'Thin'],
#   ['Woodland', 'Farmland', 'Grassland', 'Urban and suburban']],
#  ['Woodpigeon',
#   'Columba palumbus',
#   '40-42cm',
#   '75-80cm',
#   '480-550g',
#   '5,150,000 pairs',
#   nan,
#   'Woodpigeon (juvenile)',
#   ['Black', 'Blue', 'Brown', 'Grey', 'Pink/purple', 'White'],
#   ['Brown', 'Pink', 'Red'],
#   ['Black', 'Brown', 'Orange'],
#   ['Medium length', 'Thin'],
#   ['Woodland', 'Farmland', 'Grassland', 'Urban and suburban']],
#  ['Blackbird',
#   'Turdus merula',
#   '24-25cm',
#   '5cm',
#   '80-100g',
#   '5,050,000 pairs',
#   '15 million',
#   'Blackbird (adult male)',
#   ['Black', 'Brown', 'White'],
#   ['Brown'],
#   ['Black', 'Brown', 'Orange', 'Yellow'],
#   ['Medium length', 'Medium thickness'],
#   ['Woodland', 'Farmland', 'Grassland', 'Urban and suburban']],
#  ['Blackbird',
#   'Turdus merula',
#   '24-25cm',
#   '5cm',
#   '80-100g',
#   '5,050,000 pairs',
#   '15 million',
#   'Blackbird (juvenile)',
#   ['Black', 'Brown', 'Cream/buff', 'Orange', 'White'],
#   ['Brown'],
#   ['Black', 'Brown', 'Yellow'],
#   ['Medium length', 'Medium thickness'],
#   ['Woodland', 'Farmland', 'Grassland', 'Urban and suburban']],
#  ['Chaffinch',
#   'Fringilla coelebs',
#   '5cm',
#   '5cm',
#   '18-29g',
#   '5.05 million',
#   nan,
#   'Chaffinch (male)',
#   ['Black',
#    'Blue',
#    'Brown',
#    'Cream/buff',
#    'Green',
#    'Grey',
#    'Orange',
#    'Pink/purple',
#    'Red',
#    'White',
#    'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black', 'Blue', 'Brown'],
#   ['Short', 'Chunky'],
#   ['Woodland', 'Farmland', 'Grassland', 'Heathland', 'Urban and suburban']],
#  ['Chaffinch',
#   'Fringilla coelebs',
#   '5cm',
#   '5cm',
#   '18-29g',
#   '5.05 million',
#   nan,
#   'Chaffinch (female)',
#   ['Black', 'Brown', 'Cream/buff', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black', 'Blue', 'Brown'],
#   ['Short', 'Chunky'],
#   ['Woodland', 'Farmland', 'Grassland', 'Heathland', 'Urban and suburban']],
#  ['Blue tit',
#   'Cyanistes caeruleus',
#   '12cm',
#   '18cm',
#   '11g',
#   '3,400,000 territories',
#   '15 million',
#   'Blue tit',
#   ['Black', 'Blue', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Blue', 'Grey'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Blue tit',
#   'Cyanistes caeruleus',
#   '12cm',
#   '18cm',
#   '11g',
#   '3,400,000 territories',
#   '15 million',
#   'Blue tit (juvenile)',
#   ['Black', 'Blue', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Blue', 'Grey'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Great tit',
#   'Parus major',
#   '14cm',
#   '24cm',
#   '18g',
#   '2,350,000 territories',
#   nan,
#   'Great tit',
#   ['Black', 'Blue', 'Cream/buff', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Grey'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Great tit',
#   'Parus major',
#   '14cm',
#   '24cm',
#   '18g',
#   '2,350,000 territories',
#   nan,
#   'Great tit (juvenile)',
#   ['Black', 'Blue', 'Cream/buff', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Grey'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Starling',
#   'Sturnus vulgaris',
#   '21cm',
#   '37-42cm',
#   '75-90g',
#   '1.75 million',
#   nan,
#   'Starling (adult)',
#   ['Black',
#    'Blue',
#    'Brown',
#    'Cream/buff',
#    'Green',
#    'Grey',
#    'Pink/purple',
#    'White'],
#   ['Brown', 'Pink'],
#   ['Black', 'Yellow'],
#   ['Medium length', 'Powerful', 'Thin'],
#   ['Woodland',
#    'Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Upland',
#    'Urban and suburban',
#    'Wetland']],
#  ['Starling',
#   'Sturnus vulgaris',
#   '21cm',
#   '37-42cm',
#   '75-90g',
#   '1.75 million',
#   nan,
#   'Starling (juvenile)',
#   ['Black', 'Brown', 'Cream/buff', 'White'],
#   ['Brown', 'Pink'],
#   ['Black'],
#   ['Medium length', 'Powerful', 'Thin'],
#   ['Woodland',
#    'Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Upland',
#    'Urban and suburban',
#    'Wetland']],
#  ['Goldfinch',
#   'Carduelis carduelis',
#   '12cm',
#   '5cm',
#   '14-19g',
#   '1.65 million',
#   nan,
#   'Goldfinch (adult)',
#   ['Black', 'Brown', 'Cream/buff', 'Red', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black', 'Brown', 'Red'],
#   ['Short', 'Chunky'],
#   ['Farmland', 'Urban and suburban']],
#  ['Goldfinch',
#   'Carduelis carduelis',
#   '12cm',
#   '5cm',
#   '14-19g',
#   '1.65 million',
#   nan,
#   'Goldfinch (juvenile)',
#   ['Black', 'Brown', 'Cream/buff', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black', 'Brown', 'Red'],
#   ['Short', 'Chunky'],
#   ['Farmland', 'Urban and suburban']],
#  ['Collared dove',
#   'Streptopelia decaocto',
#   '32 cm',
#   '51 cm',
#   '200 g',
#   '810,000 pairs',
#   nan,
#   'Collared dove',
#   ['Black', 'Brown', 'Cream/buff', 'Grey', 'Pink/purple', 'White'],
#   ['Brown', 'Pink', 'Red'],
#   ['Black'],
#   ['Medium length', 'Thin'],
#   ['Farmland', 'Urban and suburban']],
#  ['Coal tit',
#   'Periparus ater',
#   '5cm',
#   '17-21cm',
#   '8-10g',
#   '660,000 territories',
#   nan,
#   'Coal tit',
#   ['Black', 'Brown', 'Cream/buff', 'Grey', 'White', 'Yellow'],
#   ['Grey'],
#   ['Black'],
#   ['Short', 'Thin'],
#   ['Woodland', 'Heathland', 'Urban and suburban']],
#  ['Rock dove/Feral pigeon',
#   'Columba livia',
#   '31-34cm',
#   '63-70cm',
#   '230-370g',
#   '465,000 pairs',
#   nan,
#   'Rock dove (feral pigeon)',
#   ['Black', 'Blue', 'Brown', 'Cream/buff', 'Grey', 'Pink/purple', 'White'],
#   ['Brown', 'Pink', 'Red'],
#   ['Black'],
#   ['Medium length', 'Thin'],
#   ['Farmland', 'Marine and intertidal', 'Urban and suburban']],
#  ['Herring gull',
#   'Larus argentatus',
#   '54-60cm',
#   '130-150cm',
#   '690-1440g',
#   '130,000 pairs',
#   '740,000 birds',
#   'Herring gull',
#   ['Black', 'Grey', 'White'],
#   ['Pink'],
#   ['Red', 'Yellow'],
#   ['Medium length', 'Powerful', 'Chunky'],
#   ['Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Urban and suburban',
#    'Wetland']],
#  ['Herring gull',
#   'Larus argentatus',
#   '54-60cm',
#   '130-150cm',
#   '690-1440g',
#   '130,000 pairs',
#   '740,000 birds',
#   'Herring gull (first-winter plumage)',
#   ['Black', 'Brown', 'Cream/buff', 'Grey'],
#   ['Pink'],
#   ['Black', 'Brown'],
#   ['Medium length', 'Powerful', 'Chunky'],
#   ['Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Urban and suburban',
#    'Wetland']],
#  ['Herring gull',
#   'Larus argentatus',
#   '54-60cm',
#   '130-150cm',
#   '690-1440g',
#   '130,000 pairs',
#   '740,000 birds',
#   'Herring gull (second-winter plumage)',
#   ['Black', 'Brown', 'Cream/buff', 'Grey', 'White'],
#   ['Pink'],
#   ['Black', 'Brown', 'Red'],
#   ['Medium length', 'Powerful', 'Chunky'],
#   ['Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Urban and suburban',
#    'Wetland']],
#  ['Jackdaw',
#   'Corvus monedula',
#   '34 cm',
#   '70 cm',
#   '220 g',
#   '1,550,000 pairs',
#   nan,
#   'Jackdaw',
#   ['Black', 'Grey'],
#   ['Black'],
#   ['Black'],
#   ['Medium length', 'Chunky'],
#   ['Woodland', 'Farmland', 'Grassland', 'Upland', 'Urban and suburban']],
#  ['Carrion crow',
#   'Corvus corone',
#   '45-47cm',
#   '93-104cm',
#   '370-650g',
#   '1,050,000 territories',
#   nan,
#   'Carrion crow',
#   ['Black'],
#   ['Black'],
#   ['Black'],
#   ['Medium length', 'Powerful', 'Chunky'],
#   ['Woodland',
#    'Farmland',
#    'Grassland',
#    'Heathland',
#    'Upland',
#    'Urban and suburban',
#    'Wetland']],
#  ['Black-headed gull',
#   'Chroicocephalus ridibundus',
#   '34-37cm',
#   '100-110cm',
#   '200-400g',
#   '140,000 pairs',
#   '2.2 million',
#   'Black-headed gull (summer plumage)',
#   ['Black', 'Brown', 'Grey', 'White'],
#   ['Brown', 'Red'],
#   ['Black', 'Orange', 'Red'],
#   ['Medium length', 'Medium thickness'],
#   ['Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Urban and suburban',
#    'Wetland']],
#  ['Black-headed gull',
#   'Chroicocephalus ridibundus',
#   '34-37cm',
#   '100-110cm',
#   '200-400g',
#   '140,000 pairs',
#   '2.2 million',
#   'Black-headed gull (winter plumage)',
#   ['Black', 'Grey', 'White'],
#   ['Brown', 'Orange', 'Red'],
#   ['Black', 'Orange', 'Red'],
#   ['Medium length', 'Medium thickness'],
#   ['Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Urban and suburban',
#    'Wetland']],
#  ['Black-headed gull',
#   'Chroicocephalus ridibundus',
#   '34-37cm',
#   '100-110cm',
#   '200-400g',
#   '140,000 pairs',
#   '2.2 million',
#   'Black-headed gull (first-winter plumage)',
#   ['Black', 'Brown', 'Cream/buff', 'Grey', 'White'],
#   ['Brown', 'Orange'],
#   ['Black', 'Orange', 'Red'],
#   ['Medium length', 'Medium thickness'],
#   ['Farmland', 'Marine and intertidal', 'Urban and suburban', 'Wetland']],
#  ['Black-headed gull',
#   'Chroicocephalus ridibundus',
#   '34-37cm',
#   '100-110cm',
#   '200-400g',
#   '140,000 pairs',
#   '2.2 million',
#   'Black-headed gull (juvenile)',
#   ['Black', 'Brown', 'Cream/buff', 'Grey', 'White'],
#   ['Brown', 'Orange', 'Red'],
#   ['Black', 'Brown', 'Orange', 'Red'],
#   ['Medium length', 'Medium thickness'],
#   ['Farmland',
#    'Grassland',
#    'Marine and intertidal',
#    'Urban and suburban',
#    'Wetland']],
#  ['Greenfinch',
#   'Chloris chloris',
#   '15cm',
#   '26cm',
#   '28g',
#   '785,000 pairs',
#   nan,
#   'Greenfinch (adult)',
#   ['Black', 'Brown', 'Cream/buff', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black', 'Brown'],
#   ['Short', 'Chunky'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Greenfinch',
#   'Chloris chloris',
#   '15cm',
#   '26cm',
#   '28g',
#   '785,000 pairs',
#   nan,
#   'Greenfinch (juvenile)',
#   ['Black', 'Brown', 'Cream/buff', 'Green', 'Grey', 'White', 'Yellow'],
#   ['Brown', 'Pink'],
#   ['Black', 'Brown'],
#   ['Short', 'Chunky'],
#   ['Woodland', 'Farmland', 'Urban and suburban']],
#  ['Magpie',
#   'Pica pica',
#   '44-46cm',
#   '52-60cm',
#   '200-250g',
#   '610,000 territories',
#   nan,
#   'Magpie',
#   ['Black', 'Blue', 'Green', 'White'],
#   ['Black'],
#   ['Black'],
#   ['Medium length', 'Powerful', 'Chunky'],
#   ['Woodland',
#    'Farmland',
#    'Grassland',
#    'Heathland',
#    'Upland',
#    'Urban and suburban',
#    'Wetland']]]

# %%
bird_columns = ['species','scientific_name','diet','length_(cm)','wingspan_(cm)','weight_(g)','population_breeding','population_wintering','variation','feather_colour','leg_colour','beak_colour','beak_shape','natural_habitats']

df = pd.DataFrame(data=bird_data, columns=bird_columns) ## Creating a pandas dataframe with all my data
df ## Looking at the dataframe
# Out:
#                    species             scientific_name  \
# 0                     Wren     Troglodytes troglodytes
# 1                    Robin          Erithacus rubecula
# 2                    Robin          Erithacus rubecula
# 3            House sparrow           Passer domesticus
# 4            House sparrow           Passer domesticus
# 5               Woodpigeon            Columba palumbus
# 6               Woodpigeon            Columba palumbus
# 7                Blackbird               Turdus merula
# 8                Blackbird               Turdus merula
# 9                Chaffinch           Fringilla coelebs
# 10               Chaffinch           Fringilla coelebs
# 11                Blue tit         Cyanistes caeruleus
# 12                Blue tit         Cyanistes caeruleus
# 13               Great tit                 Parus major
# 14               Great tit                 Parus major
# 15                Starling            Sturnus vulgaris
# 16                Starling            Sturnus vulgaris
# 17               Goldfinch         Carduelis carduelis
# 18               Goldfinch         Carduelis carduelis
# 19           Collared dove       Streptopelia decaocto
# 20                Coal tit              Periparus ater
# 21  Rock dove/Feral pigeon               Columba livia
# 22            Herring gull            Larus argentatus
# 23            Herring gull            Larus argentatus
# 24            Herring gull            Larus argentatus
# 25                 Jackdaw             Corvus monedula
# 26            Carrion crow               Corvus corone
# 27       Black-headed gull  Chroicocephalus ridibundus
# 28       Black-headed gull  Chroicocephalus ridibundus
# 29       Black-headed gull  Chroicocephalus ridibundus
# 30       Black-headed gull  Chroicocephalus ridibundus
# 31              Greenfinch             Chloris chloris
# 32              Greenfinch             Chloris chloris
# 33                  Magpie                   Pica pica
#
#                                                  diet length_(cm)  \
# 0                                Insects and spiders.      9-10cm
# 1   Worms, seeds, fruits, insects and other invert...        14cm
# 2   Worms, seeds, fruits, insects and other invert...        14cm
# 3                                   Seeds and scraps.     14-15cm
# 4                                   Seeds and scraps.     14-15cm
# 5   Crops like cabbages, sprouts, peas and grain. ...     40-42cm
# 6   Crops like cabbages, sprouts, peas and grain. ...     40-42cm
# 7   Blackbird food consists of a variety of insect...     24-25cm
# 8   Blackbird food consists of a variety of insect...     24-25cm
# 9                                  Insects and seeds.      14.5cm
# 10                                 Insects and seeds.      14.5cm
# 11             Insects, caterpillars, seeds and nuts.        12cm
# 12             Insects, caterpillars, seeds and nuts.        12cm
# 13                           Insects, seeds and nuts.        14cm
# 14                           Insects, seeds and nuts.        14cm
# 15                           Invertebrates and fruit.        21cm
# 16                           Invertebrates and fruit.        21cm
# 17                       Seeds and insects in summer.        12cm
# 18                       Seeds and insects in summer.        12cm
# 19                    Seeds, grains, buds and shoots.       32 cm
# 20                           Insects, seeds and nuts.      11.5cm
# 21                                 Seeds and cereals.     31-34cm
# 22  Ominivorous- carrion, offal, seeds, fruits, yo...     54-60cm
# 23  Ominivorous- carrion, offal, seeds, fruits, yo...     54-60cm
# 24  Ominivorous- carrion, offal, seeds, fruits, yo...     54-60cm
# 25  Insects, young birds and eggs, fruit, seeds an...       34 cm
# 26  Carrion, insects, worms, seeds, fruit, eggs an...     45-47cm
# 27                  Worms, insects, fish and carrion.     34-37cm
# 28                  Worms, insects, fish and carrion.     34-37cm
# 29                  Worms, insects, fish and carrion.     34-37cm
# 30                  Worms, insects, fish and carrion.     34-37cm
# 31                                 Seeds and insects.        15cm
# 32                                 Seeds and insects.        15cm
# 33                            Omnivore and scavenger.     44-46cm
#
#    wingspan_(cm) weight_(g)     population_breeding population_wintering  \
# 0        13-17cm      7-12g  11,000,000 territories                  NaN
# 1        20-22cm     14-21g   7,350,000 territories                  NaN
# 2        20-22cm     14-21g   7,350,000 territories                  NaN
# 3      21-25.5cm     24-38g         5,300,000 pairs                  NaN
# 4      21-25.5cm     24-38g         5,300,000 pairs                  NaN
# 5        75-80cm   480-550g         5,150,000 pairs                  NaN
# 6        75-80cm   480-550g         5,150,000 pairs                  NaN
# 7      34-38.5cm    80-100g         5,050,000 pairs           15 million
# 8      34-38.5cm    80-100g         5,050,000 pairs           15 million
# 9    24.5-28.5cm     18-29g            5.05 million                  NaN
# 10   24.5-28.5cm     18-29g            5.05 million                  NaN
# 11          18cm        11g   3,400,000 territories           15 million
# 12          18cm        11g   3,400,000 territories           15 million
# 13          24cm        18g   2,350,000 territories                  NaN
# 14          24cm        18g   2,350,000 territories                  NaN
# 15       37-42cm     75-90g            1.75 million                  NaN
# 16       37-42cm     75-90g            1.75 million                  NaN
# 17     21-25.5cm     14-19g            1.65 million                  NaN
# 18     21-25.5cm     14-19g            1.65 million                  NaN
# 19         51 cm      200 g           810,000 pairs                  NaN
# 20       17-21cm      8-10g     660,000 territories                  NaN
# 21       63-70cm   230-370g           465,000 pairs                  NaN
# 22     130-150cm  690-1440g           130,000 pairs        740,000 birds
# 23     130-150cm  690-1440g           130,000 pairs        740,000 birds
# 24     130-150cm  690-1440g           130,000 pairs        740,000 birds
# 25         70 cm      220 g         1,550,000 pairs                  NaN
# 26      93-104cm   370-650g   1,050,000 territories                  NaN
# 27     100-110cm   200-400g           140,000 pairs          2.2 million
# 28     100-110cm   200-400g           140,000 pairs          2.2 million
# 29     100-110cm   200-400g           140,000 pairs          2.2 million
# 30     100-110cm   200-400g           140,000 pairs          2.2 million
# 31          26cm        28g           785,000 pairs                  NaN
# 32          26cm        28g           785,000 pairs                  NaN
# 33       52-60cm   200-250g     610,000 territories                  NaN
#
#                                    variation  \
# 0                                       Wren
# 1                              Robin (adult)
# 2                           Robin (juvenile)
# 3                 House sparrow (adult male)
# 4               House sparrow (adult female)
# 5                         Woodpigeon (adult)
# 6                      Woodpigeon (juvenile)
# 7                     Blackbird (adult male)
# 8                       Blackbird (juvenile)
# 9                           Chaffinch (male)
# 10                        Chaffinch (female)
# 11                                  Blue tit
# 12                       Blue tit (juvenile)
# 13                                 Great tit
# 14                      Great tit (juvenile)
# 15                          Starling (adult)
# 16                       Starling (juvenile)
# 17                         Goldfinch (adult)
# 18                      Goldfinch (juvenile)
# 19                             Collared dove
# 20                                  Coal tit
# 21                  Rock dove (feral pigeon)
# 22                              Herring gull
# 23       Herring gull (first-winter plumage)
# 24      Herring gull (second-winter plumage)
# 25                                   Jackdaw
# 26                              Carrion crow
# 27        Black-headed gull (summer plumage)
# 28        Black-headed gull (winter plumage)
# 29  Black-headed gull (first-winter plumage)
# 30              Black-headed gull (juvenile)
# 31                        Greenfinch (adult)
# 32                     Greenfinch (juvenile)
# 33                                    Magpie
#
#                                        feather_colour            leg_colour  \
# 0                          [Brown, Cream/buff, White]         [Brown, Pink]
# 1   [Brown, Cream/buff, Grey, Orange, Red, White, ...         [Brown, Pink]
# 2          [Brown, Cream/buff, Orange, White, Yellow]         [Brown, Pink]
# 3             [Black, Brown, Cream/buff, Grey, White]         [Brown, Pink]
# 4                           [Brown, Cream/buff, Grey]         [Brown, Pink]
# 5      [Black, Blue, Brown, Grey, Pink/purple, White]    [Brown, Pink, Red]
# 6      [Black, Blue, Brown, Grey, Pink/purple, White]    [Brown, Pink, Red]
# 7                               [Black, Brown, White]               [Brown]
# 8           [Black, Brown, Cream/buff, Orange, White]               [Brown]
# 9   [Black, Blue, Brown, Cream/buff, Green, Grey, ...         [Brown, Pink]
# 10  [Black, Brown, Cream/buff, Green, Grey, White,...         [Brown, Pink]
# 11          [Black, Blue, Green, Grey, White, Yellow]          [Blue, Grey]
# 12          [Black, Blue, Green, Grey, White, Yellow]          [Blue, Grey]
# 13  [Black, Blue, Cream/buff, Green, Grey, White, ...                [Grey]
# 14  [Black, Blue, Cream/buff, Green, Grey, White, ...                [Grey]
# 15  [Black, Blue, Brown, Cream/buff, Green, Grey, ...         [Brown, Pink]
# 16                  [Black, Brown, Cream/buff, White]         [Brown, Pink]
# 17     [Black, Brown, Cream/buff, Red, White, Yellow]         [Brown, Pink]
# 18          [Black, Brown, Cream/buff, White, Yellow]         [Brown, Pink]
# 19  [Black, Brown, Cream/buff, Grey, Pink/purple, ...    [Brown, Pink, Red]
# 20    [Black, Brown, Cream/buff, Grey, White, Yellow]                [Grey]
# 21  [Black, Blue, Brown, Cream/buff, Grey, Pink/pu...    [Brown, Pink, Red]
# 22                               [Black, Grey, White]                [Pink]
# 23                   [Black, Brown, Cream/buff, Grey]                [Pink]
# 24            [Black, Brown, Cream/buff, Grey, White]                [Pink]
# 25                                      [Black, Grey]               [Black]
# 26                                            [Black]               [Black]
# 27                        [Black, Brown, Grey, White]          [Brown, Red]
# 28                               [Black, Grey, White]  [Brown, Orange, Red]
# 29            [Black, Brown, Cream/buff, Grey, White]       [Brown, Orange]
# 30            [Black, Brown, Cream/buff, Grey, White]  [Brown, Orange, Red]
# 31  [Black, Brown, Cream/buff, Green, Grey, White,...         [Brown, Pink]
# 32  [Black, Brown, Cream/buff, Green, Grey, White,...         [Brown, Pink]
# 33                        [Black, Blue, Green, White]               [Black]
#
#                        beak_colour                         beak_shape  \
# 0                          [Black]              [Short, Curved, Thin]
# 1                          [Black]                      [Short, Thin]
# 2                          [Black]                      [Short, Thin]
# 3                   [Black, Brown]                    [Short, Chunky]
# 4                   [Black, Brown]                    [Short, Chunky]
# 5           [Black, Brown, Orange]              [Medium length, Thin]
# 6           [Black, Brown, Orange]              [Medium length, Thin]
# 7   [Black, Brown, Orange, Yellow]  [Medium length, Medium thickness]
# 8           [Black, Brown, Yellow]  [Medium length, Medium thickness]
# 9             [Black, Blue, Brown]                    [Short, Chunky]
# 10            [Black, Blue, Brown]                    [Short, Chunky]
# 11                         [Black]                      [Short, Thin]
# 12                         [Black]                      [Short, Thin]
# 13                         [Black]                      [Short, Thin]
# 14                         [Black]                      [Short, Thin]
# 15                 [Black, Yellow]    [Medium length, Powerful, Thin]
# 16                         [Black]    [Medium length, Powerful, Thin]
# 17             [Black, Brown, Red]                    [Short, Chunky]
# 18             [Black, Brown, Red]                    [Short, Chunky]
# 19                         [Black]              [Medium length, Thin]
# 20                         [Black]                      [Short, Thin]
# 21                         [Black]              [Medium length, Thin]
# 22                   [Red, Yellow]  [Medium length, Powerful, Chunky]
# 23                  [Black, Brown]  [Medium length, Powerful, Chunky]
# 24             [Black, Brown, Red]  [Medium length, Powerful, Chunky]
# 25                         [Black]            [Medium length, Chunky]
# 26                         [Black]  [Medium length, Powerful, Chunky]
# 27            [Black, Orange, Red]  [Medium length, Medium thickness]
# 28            [Black, Orange, Red]  [Medium length, Medium thickness]
# 29            [Black, Orange, Red]  [Medium length, Medium thickness]
# 30     [Black, Brown, Orange, Red]  [Medium length, Medium thickness]
# 31                  [Black, Brown]                    [Short, Chunky]
# 32                  [Black, Brown]                    [Short, Chunky]
# 33                         [Black]  [Medium length, Powerful, Chunky]
#
#                                      natural_habitats
# 0   [Woodland, Farmland, Heathland, Urban and subu...
# 1            [Woodland, Farmland, Urban and suburban]
# 2            [Woodland, Farmland, Urban and suburban]
# 3                      [Farmland, Urban and suburban]
# 4                      [Farmland, Urban and suburban]
# 5   [Woodland, Farmland, Grassland, Urban and subu...
# 6   [Woodland, Farmland, Grassland, Urban and subu...
# 7   [Woodland, Farmland, Grassland, Urban and subu...
# 8   [Woodland, Farmland, Grassland, Urban and subu...
# 9   [Woodland, Farmland, Grassland, Heathland, Urb...
# 10  [Woodland, Farmland, Grassland, Heathland, Urb...
# 11           [Woodland, Farmland, Urban and suburban]
# 12           [Woodland, Farmland, Urban and suburban]
# 13           [Woodland, Farmland, Urban and suburban]
# 14           [Woodland, Farmland, Urban and suburban]
# 15  [Woodland, Farmland, Grassland, Marine and int...
# 16  [Woodland, Farmland, Grassland, Marine and int...
# 17                     [Farmland, Urban and suburban]
# 18                     [Farmland, Urban and suburban]
# 19                     [Farmland, Urban and suburban]
# 20          [Woodland, Heathland, Urban and suburban]
# 21  [Farmland, Marine and intertidal, Urban and su...
# 22  [Farmland, Grassland, Marine and intertidal, U...
# 23  [Farmland, Grassland, Marine and intertidal, U...
# 24  [Farmland, Grassland, Marine and intertidal, U...
# 25  [Woodland, Farmland, Grassland, Upland, Urban ...
# 26  [Woodland, Farmland, Grassland, Heathland, Upl...
# 27  [Farmland, Grassland, Marine and intertidal, U...
# 28  [Farmland, Grassland, Marine and intertidal, U...
# 29  [Farmland, Marine and intertidal, Urban and su...
# 30  [Farmland, Grassland, Marine and intertidal, U...
# 31           [Woodland, Farmland, Urban and suburban]
# 32           [Woodland, Farmland, Urban and suburban]
# 33  [Woodland, Farmland, Grassland, Heathland, Upl...

# %%
## Saving the data to a csv
df.to_csv('birds_19_common.csv', index=False)
